# %%
import numpy as np
import scipy as sp
import pandas as pd
import networkx as nx
import ray, importlib
import graphs, read, propagation
importlib.reload(propagation)
# Out:
# <module 'propagation' from '/Users/ian/src/kpm/propagation.py'>

# %%
#ray.init()

# %%
datadir = '/Users/ian/Nextcloud'
# datadir = '/home/sarming'
#read.adjlist(f'{datadir}/anonymized_outer_graph_neos_20200311.adjlist',
#              save_as=f'{datadir}/outer_neos.npz')
sim = propagation.Simulation.from_files(f'{datadir}/outer_neos.npz', f'{datadir}/authors_tweets_features_neos.csv' )
features = sim.features
params = sim.params
stats = sim.stats

# %%
type(stats.loc[('0000','0000'),'tweets'])
# Out:
# numpy.int64

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 166 entries, (0000, 0000) to (1101, 1111)
# Data columns (total 4 columns):
# tweets       166 non-null Int64
# retweeted    166 non-null Int64
# retweets     166 non-null Int64
# sources      166 non-null object
# dtypes: Int64(3), object(1)
# memory usage: 12.7+ KB

# %%
stats.loc[('0000','0000')]
# Out:
# tweets                                                     275
# retweeted                                                   68
# retweets                                                   301
# sources      [13216, 24601, 122972, 159719, 47056, 14934, 8...
# Name: (0000, 0000), dtype: object

# %%
sim.search_parameters(1,0.5)
# Out:
# /Users/ian/anaconda3/envs/hidalgo/lib/python3.7/site-packages/pandas/core/indexes/multi.py:2013: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   new_codes = [level_codes[key] for level_codes in self.codes]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-6397383ef106> in <module>
# ----> 1 features[['tweets']]
#       2
#
# ~/anaconda3/envs/hidalgo/lib/python3.7/site-packages/pandas/core/indexes/multi.py in __getitem__(self, key)
#    2011                     key = np.asarray(key)
#    2012
# -> 2013             new_codes = [level_codes[key] for level_codes in self.codes]
#    2014
#    2015             return MultiIndex(
#
# ~/anaconda3/envs/hidalgo/lib/python3.7/site-packages/pandas/core/indexes/multi.py in <listcomp>(.0)
#    2011                     key = np.asarray(key)
#    2012
# -> 2013             new_codes = [level_codes[key] for level_codes in self.codes]
#    2014
#    2015             return MultiIndex(
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
sim.search_parameters(200,0.0001)

# %%
features.to_csv('features_200_0.0001.csv')

# %%
csv=pd.read_csv(f'{datadir}/authors_tweets_features_neos.csv' )
csv['author_feature']=list(zip(csv.))

# %%
list(params)

# %%
[(x) for x,y in params]

# %%
p=ray.get(params)

# %% [raw]
# pool = ray.util.multiprocessing.Pool(processes=32)

# %%
 def helper(feature):
        sim.search_parameters(100,0.00001)
    sample_calls = [(A, coef, random_vector(n)) for _ in range(num_samples)]
s = sum(pool.starmap(chebyshev_sample, sample_calls))

# %%
list(sim.simulate(sim.sample_feature(10)))

# %%
sim.sample_source('0000',size=None)

# %%
tweets.dropna().groupby('author_feature')['source'].unique()

# %%
sim.sample_source('0000',1)[0]
# features.loc[('0000','0011')]

# %%
af = features.groupby('author_feature')['tweets'].sum()
af /= af.sum()
np.random.choice(af.index,size=1,p=af)

# %%
with pd.option_context("display.max_rows", 1000): display(sim.features)

# %%
sim.sample_source('0000',size=None)

# %%
tweets.dropna().groupby('author_feature')['source'].unique()

# %%
sim.sample_source('0000',1)[0]
# features.loc[('0000','0011')]

# %%
af = features.groupby('author_feature')['tweets'].sum()
af /= af.sum()
np.random.choice(af.index,size=1,p=af)

# %%
with pd.option_context("display.max_rows", 1000): display(sim.features)
# Out:
#                               tweets  retweeted  retweets      freq  \
# author_feature tweet_feature
# 0000           0000              275       68.0     301.0  0.036883
#                0001               17        4.0      31.0  0.002280
#                0010              221       57.0     373.0  0.029641
#                0011               32       11.0      31.0  0.004292
#                0100               35        4.0      38.0  0.004694
#                0101                1        1.0       3.0  0.000134
#                0110               57       29.0     183.0  0.007645
#                0111                5        1.0       1.0  0.000671
#                1000              363      124.0     614.0  0.048686
#                1001               30       12.0      29.0  0.004024
#                1010              378      125.0     588.0  0.050697
#                1011               65       35.0     284.0  0.008718
#                1100               65       25.0      92.0  0.008718
#                1101                2        0.0       0.0  0.000268
#                1110               73       33.0     155.0  0.009791
#                1111                8        3.0      20.0  0.001073
# 0001           0000              208       80.0     568.0  0.027897
#                0001               13        9.0     153.0  0.001744
#                0010              167       65.0     699.0  0.022398
#                0011               36       19.0     318.0  0.004828
#                0100               62       14.0      80.0  0.008315
#                0101               26       20.0     185.0  0.003487
#                0110               46       25.0     275.0  0.006170
#                0111               10        8.0      53.0  0.001341
#                1000              271      142.0    1289.0  0.036347
#                1001               73       56.0    1044.0  0.009791
#                1010              331      152.0    1036.0  0.044394
#                1011               86       55.0     397.0  0.011534
#                1100               83       35.0     393.0  0.011132
#                1101               63       35.0     266.0  0.008450
#                1110               81       42.0     268.0  0.010864
#                1111               33       17.0      64.0  0.004426
# 0010           0000              402       76.0     291.0  0.053916
#                0001                2        1.0      39.0  0.000268
#                0010              278       75.0     299.0  0.037285
#                0011               38       18.0     120.0  0.005097
#                0100               38        7.0      61.0  0.005097
#                0101                4        1.0       1.0  0.000536
#                0110               51       27.0      77.0  0.006840
#                0111                2        0.0       0.0  0.000268
#                1000              285       61.0     266.0  0.038224
#                1001               37       12.0      44.0  0.004962
#                1010              468      173.0     904.0  0.062768
#                1011               69       33.0     117.0  0.009254
#                1100               61       17.0      30.0  0.008181
#                1101                9        2.0       7.0  0.001207
#                1110               48       23.0      68.0  0.006438
#                1111                1        0.0       0.0  0.000134
# 0011           0000               90       29.0     375.0  0.012071
#                0001                1        1.0      43.0  0.000134
#                0010               67       28.0     204.0  0.008986
#                0011               19       11.0     185.0  0.002548
#                0100               40       12.0      48.0  0.005365
#                0101                3        1.0       2.0  0.000402
#                0110               18        9.0      67.0  0.002414
#                0111                2        2.0       8.0  0.000268
#                1000               86       30.0     237.0  0.011534
#                1001               20        5.0     117.0  0.002682
#                1010              210       82.0     431.0  0.028165
#                1011               24       14.0     113.0  0.003219
#                1100               29        7.0      23.0  0.003889
#                1101               10        4.0      41.0  0.001341
#                1110               16        9.0      22.0  0.002146
#                1111               10        7.0      22.0  0.001341
# 0100           0000              113       39.0     115.0  0.015156
#                0001                5        1.0       3.0  0.000671
#                0010               47       17.0     144.0  0.006304
#                0011                6        4.0      10.0  0.000805
#                0100               20        1.0       2.0  0.002682
#                0110                8        1.0       1.0  0.001073
#                1000               84       34.0     129.0  0.011266
#                1001                4        4.0      24.0  0.000536
#                1010               76       14.0      35.0  0.010193
#                1011               14        4.0      23.0  0.001878
#                1100               13        2.0       2.0  0.001744
#                1110                9        1.0       1.0  0.001207
#                1111                1        1.0       1.0  0.000134
# 0101           0000               40       13.0      58.0  0.005365
#                0001                2        1.0       4.0  0.000268
#                0010               27       10.0     168.0  0.003621
#                0011                4        3.0       7.0  0.000536
#                0100               34       11.0      46.0  0.004560
#                0101                4        1.0       2.0  0.000536
#                0110                3        0.0       0.0  0.000402
#                0111                4        2.0      10.0  0.000536
#                1000               24        9.0      29.0  0.003219
#                1001                4        2.0       5.0  0.000536
#                1010               39       23.0     200.0  0.005231
#                1011                9        7.0      57.0  0.001207
#                1100               27        1.0       8.0  0.003621
#                1110                6        5.0      90.0  0.000805
#                1111                1        1.0       8.0  0.000134
# 0110           0000               84       30.0      85.0  0.011266
#                0010               53       18.0      59.0  0.007108
#                0011                6        4.0      25.0  0.000805
#                0100               37        5.0      12.0  0.004962
#                0101                1        1.0       1.0  0.000134
#                0110               14        3.0       9.0  0.001878
#                1000               59       23.0      69.0  0.007913
#                1001               18        5.0       6.0  0.002414
#                1010               74       30.0     172.0  0.009925
#                1011               15        3.0       6.0  0.002012
#                1100               10        5.0      14.0  0.001341
#                1101                1        0.0       0.0  0.000134
#                1110               10        4.0      21.0  0.001341
# 0111           0000               41       13.0      26.0  0.005499
#                0001                2        0.0       0.0  0.000268
#                0010               20        9.0      20.0  0.002682
#                0011                3        1.0       1.0  0.000402
#                0100                4        2.0       4.0  0.000536
#                0101               29        0.0       0.0  0.003889
#                0110                2        1.0       3.0  0.000268
#                1000               12        6.0      11.0  0.001609
#                1001                2        1.0       1.0  0.000268
#                1010               20        5.0      12.0  0.002682
#                1011                4        2.0       3.0  0.000536
#                1100                3        3.0      30.0  0.000402
# 1000           0000                7        7.0     305.0  0.000939
#                0001                1        1.0      12.0  0.000134
#                0010                5        4.0      92.0  0.000671
#                0011                4        3.0      28.0  0.000536
#                1000                4        2.0      95.0  0.000536
#                1100                2        1.0       3.0  0.000268
# 1001           0000               19       15.0     253.0  0.002548
#                0001                2        2.0      26.0  0.000268
#                0010               10        7.0      77.0  0.001341
#                0011               12        9.0      59.0  0.001609
#                0100                8        6.0      58.0  0.001073
#                0101                1        0.0       0.0  0.000134
#                0110               10        5.0      12.0  0.001341
#                0111                3        3.0      20.0  0.000402
#                1000               16       15.0     297.0  0.002146
#                1001               12        5.0      21.0  0.001609
#                1010               36       32.0     205.0  0.004828
#                1011               21       16.0     132.0  0.002817
#                1100                8        4.0      19.0  0.001073
#                1101                3        1.0       1.0  0.000402
#                1110               23       22.0      95.0  0.003085
#                1111                3        2.0      19.0  0.000402
# 1010           0000                1        1.0       1.0  0.000134
#                0010                1        1.0       1.0  0.000134
#                1000                1        1.0      19.0  0.000134
#                1010                2        2.0      10.0  0.000268
# 1011           0000                2        2.0       5.0  0.000268
#                0010                5        3.0      11.0  0.000671
#                0110                1        1.0       1.0  0.000134
#                1010                5        1.0       2.0  0.000671
#                1011                2        2.0       8.0  0.000268
